# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.loadtxt("out.csv", delimiter=",", skiprows=0)
time,area,volume,helfrich,kinetic=data.T

tn = data.shape[0]

start_i = 7
end_i = tn 

plt.plot(time[start_i:end_i], kinetic[start_i:end_i])
plt.scatter(time[start_i:end_i], kinetic[start_i:end_i])
plt.show()

plt.plot(time[start_i:end_i], helfrich[start_i:end_i])
plt.scatter(time[start_i:end_i], helfrich[start_i:end_i])
plt.show()
